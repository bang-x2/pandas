# %% [markdown]
# # 기본 함수만들기

# %%
result = 0

def add(num):
    global result
    result += num
    return result
def miner(num):
    global result
    result -= num
    return result
print(add(3))
print(add(4))
# Out:
# 3
# 7

# %%
add(3)
# Out:
# 10

# %%
miner(4)
# Out:
# 6

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result += num
        return self.result

cal1 = Calculator()
cal2 = Calculator()

print(cal1.add(3))
print(cal1.add(4))
print(cal2.add(3))
print(cal2.add(7))
# Out:
# 3
# 7
# 3
# 10

# %%
class FourCal:
    def setdata(self,first,second):
        self.first = first
        self.second = second

# %%
a = FourCal()
a.setdata(4, 2)
print(a.first)

# %% [markdown]
# ![GOMCAM%2020211103_2333460229.png](attachment:GOMCAM%2020211103_2333460229.png)

# %%
b = FourCal() # 빵틀로 객체를 만들어 b에 담아 준다.
b.setdata(3, 7) # 객체안에 setdata함수를 넣어준다.
print(b.first) # 함수안에 b에 담겨진
# Out:
# 3

# %%
class FourCal:
    
    def setdata(self, first, second):
        self.first = first
        self.second = second
    
    def add(self):
        result = self.first + self.second
        return result

# %%
a = FourCal()
a.setdata(3,4)
print(a.add())
# Out:
# 7
